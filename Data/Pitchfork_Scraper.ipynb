# %%
#Data storage
import numpy as np
import pandas as pd

#Scraping
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup

#General
import re
import time
import random
import pickle

# %%
#Scrape an individual album page when passed from a link
def p_review_scrape(url):
    
    #Temporary dictionary to create a row for the review
    temp_dict = dict()
    
    #Try to connect
    try:
        html = urlopen(url)
        bs = BeautifulSoup(html, 'html.parser')
        
    #If the webpage cannot be connected to, then leave
    except HTTPError as e:
        print(e)
        print("Cannot reach {}".format(url))
        time.sleep(4 + 2*random.random())
        return 'None'
    
    #Collect data from webpages, and fill in nan if info isn't available
    
    #Get artist
    try:
        temp_dict['artist'] = bs.find_all(class_ = 'single-album-tombstone__artist-links')[0].get_text()
    except:
        temp_dict['artist'] = 'Unknown'
        
    #Get album    
    try:    
        temp_dict['album'] = bs.find_all(class_ = 'single-album-tombstone__review-title')[0].get_text()
    except:
        temp_dict['album'] = 'Unknown'
        
    #Get score
    try:
        temp_dict['score'] = bs.find_all(class_ = 'score')[0].get_text()
    except:
        temp_dict['score'] = np.nan
        
    #Get labels
    try:
        for entry in bs.find_all(class_ = 'labels-list__item'):
            temp_dict['labels'] = temp_dict.get('labels', []) + [entry.get_text()]
    except:
        temp_dict['labels'] = []
            
    #Get genres
    try:
        for entry in bs.find_all(class_ = 'genre-list__item'):
            temp_dict['genres'] = temp_dict.get('genres', []) + [entry.get_text()]
    except:
        temp_dict['genre'] = []
            
    #Get year
    try:
        temp_dict['year'] = bs.find_all(class_ = 'single-album-tombstone__meta-year')[0].get_text().split()[-1]
    except:
        temp_dict['year'] = np.nan
        
    #Get author name
    try:
        temp_dict['reviewer'] = bs.find_all(class_ = 'authors-detail__display-name')[0].get_text()
    except:
        temp_dict['reviewer'] = 'Unknown'
        
    #Get author title
    try:
        temp_dict['title'] = bs.find_all(class_ = 'authors-detail__title')[0].get_text()
    except:
        temp_dict['title'] = 'None'
        
    #Get published date
    try:
        temp_dict['pub_date'] = bs.find_all(class_ = 'pub-date')[0].get_text()
    except:
        temp_dict['pub_date'] = np.nan

        
    #Get abstract
    try:
        temp_dict['abstract'] = bs.find_all(class_ = 'review-detail__abstract')[0].get_text()
    except:
        temp_dict['abstract'] = 'None'
        
    #Get review
    try:
        temp_dict['review'] = bs.find_all(class_ = 'review-detail__text')[0].get_text()
    except:
        temp_dict['review'] = 'None'
        
    #Get artwork link
    try:
        temp_dict['art'] = re.findall(r'src=.*\.jpg',str(bs.find_all(class_ = 'single-album-tombstone__art')))[0]
    except:
        temp_dict['art'] = 'Unknown'
        
    return temp_dict

# %%
test = p_review_scrape('https://pitchfork.com/reviews/albums/cut-copy-freeze-melt/')
test
# Out:
# {'artist': 'Cut Copy',
#  'album': 'Freeze, Melt',
#  'score': '6.5',
#  'labels': ['Cutters', 'The Orchard'],
#  'genres': ['Rock'],
#  'year': '2020',
#  'reviewer': 'Jesse Dorris',
#  'title': 'Contributor',
#  'pub_date': 'August 25 2020',
#  'abstract': 'The Australian electro-pop veterans return with a climate-change album both as chilled as an upscale boutique and as politically engaged as your Instagram feed.\n',
#  'review': 'Featured Tracks:Play TrackLove Is All We Share — Cut CopyVia\xa0Bandcamp\xa0/\xa0BuyCut Copy have been at it for almost 20 years, which seems impossible. They seem to exist outside of time, perhaps because they’ve been looking back from the start—immediately appealing and with a toothsome competence, but more about articulating taste than defining a singular point of view.\nMaybe bandleader Dan Whitford felt stale after 2017’s slick bummer, Haiku from Zero. Maybe the anxiety of influence had settled into ennui. For whatever reason, Whitford left his native Australia and decamped to Copenhagen, endured Scandinavia’s dark winters of the soul, and obsessed about climate change before returning to Melbourne to get the band together again. The result is an album as chilled as an upscale boutique in a heatwave and as politically engaged as your Instagram feed, which is to say very and not quite as much as it thinks.\nLead single “Love Is All We Share” is sumptuous, with an icy choir hovering at eye level and little squiggles signifying the alienation that arrived with the dial-up modem, leaving us more connected and more isolated than ever. “Dead to the world,” he sings, as beautiful chunks of harmony float by like floes in a rising sea, “can you feel it in your fingers?/Love is all we share.”  There’s more numbness than sentiment. If this “we” is us in Australia, or Denmark, or the United States—or, sadly, so much of the rest of the world—love is not all we share; rage and terror are at least two more things. Anyway, in “A Perfect Day,” Whitford is “running out of love” but does have very well recorded percussion echoing like bad thoughts, and glistening synths that can fill up an otherwise empty room. “What a perfect day,” he sings, “to be alone.”\nWords barely make it into “Stop Horizon,” a twinkler of plucked guitars and pitter-pat keyboards, as if the Orb’s “Little Fluffy Clouds” blew in some light showers. Later, a track called “Rain” arrives, and whether it signifies tears, a biblical cleanse, the flooding doom on our horizons, or a pitiless drought which will allow the West to burn unabated, it puddles beautifully. It’s basically an onomatopoeia, but the meaning washes away. Lyricless “In Transit” moves the album to a close, with little stuttering ticks of time running out for us all and a rather lovely sing-song melody that murmurs, Oh well.\n“Running in the Grass” has a bit more bite, with a sharp swiping blade of a noise that could give your eardrum a papercut. It severs the chorus (“You cut me down to the bone”) from the verses. If crowds ever gather again, it will please them. As will “Like Breaking Glass” which is mixed, like the rest of the album, by the Knife and Fever Ray collaborator Christoffer Berg. It softens those Swedes’ silent shouts into slightly hushed sighs. And opener “Cold Water” is wistful and effective, a soggier take on Portishead’s “The Rip,” soaring upward in hopes of a festival to survey. Would that it find might one.\nFestival culture, with its massive expenditures of energy and waste creation, is (was?) hell on the climate. Touring, too, not to mention the transubstantiation of fossil fuel into beautiful vinyl. If it’s hypocritical for Cut Copy to swap the joys of neon and dancing and kissing for a political agenda diametrically opposed to their own work, well, hypocrisy is the price of existence. The trick is to acknowledge reality without aestheticizing peril. The cover of Freeze, Melt nods to the conceptual artist John Baldessari, whose death at the start of 2020 might have warned us of the waves of bullshit to come. Its own concept is unimpeachable: Climate change does suck. Ice is a memory. Mostly, though, Freeze, Melt just feels like a nice warm bath.\nBack to home',
#  'art': 'src="https://media.pitchfork.com/photos/5f43c2d1f6eb11025fede8d1/1:1/w_320/Cut%20Copy.jpg'}

# %%
#Grab relevant links on a pitchfork album page
def p_url_grab(url):
    
    #Load page
    try:
        html = urlopen(url)
        bs = BeautifulSoup(html, 'html.parser')
    
        #Create a list of review urls
        url_list = []
        for entry in bs.find_all('a', {'class': 'review__link'}):
            url_list.append(entry.attrs['href'])
            
    except HTTPError as e:
        print(e)
        print('Error on {}'.format(url))
        return 'None'
        
    return url_list

# %%
test_list = p_url_grab('https://pitchfork.com/reviews/albums/?page=1')
test_list
# Out:
# ['/reviews/albums/harry-nilsson-pussy-cats/',
#  '/reviews/albums/maluma-papi-juancho/',
#  '/reviews/albums/silvia-tarozzi-mi-specchio-e-rifletto/',
#  '/reviews/albums/katy-perry-smile/',
#  '/reviews/albums/nines-crabs-in-a-bucket/',
#  '/reviews/albums/sevdaliza-shabrang/',
#  '/reviews/albums/shackleton-zimpel-primal-forms/',
#  '/reviews/albums/nas-kings-disease/',
#  '/reviews/albums/no-joy-motherhood/',
#  '/reviews/albums/dan-deacon-well-groomed-original-score/',
#  '/reviews/albums/03-greedo-ron-rontheproducer-load-it-up-vol-01/',
#  '/reviews/albums/fireboy-dml-apollo/']

# %%
#Pitchfork web crawler
def p_crawler(start_page = 1, end_page = 2):
    
    start_time = time.time()
    
    #List for storing dictionaries of entries
    data_list = []
    
    #Record start page to increment and the main site page to use to create new paths later
    current_page = start_page
    main_url = 'https://pitchfork.com'
    
    #Continue loop until you complete end_page
    while current_page <= end_page:
        
        #Grab review urls from main page (twelve at a time), then pause for a sec
        url = 'https://pitchfork.com/reviews/albums/?page={}'.format(current_page)
        url_list = p_url_grab(url)
        time.sleep(2 + 1*random.random())
        
        if url_list != 'None':
            for url in url_list:
            
                #Create actual url, get the data, add to the list, then chill out for a sec
                true_url = main_url + url
                new_row = p_review_scrape(true_url)
                if new_row != 'None':
                    data_list.append(new_row)
                time.sleep(2 + 1*random.random())
                
        current_page += 1
        print(current_page - 1, '/', end_page, time.time() - start_time)
    return data_list

# %%
crawl_test = p_crawler(start_page = 1, end_page = 2)
pd.DataFrame(crawl_test)
# Out:
# 1 / 2 45.33940243721008
# 2 / 2 91.05144619941711
#                          artist  \
# 0                 Harry Nilsson
# 1                        Maluma
# 2                Silvia Tarozzi
# 3                    Katy Perry
# 4                         Nines
# 5                     Sevdaliza
# 6              ShackletonZimpel
# 7                           Nas
# 8                        No Joy
# 9                    Dan Deacon
# 10  03 GreedoRon-RonTheProducer
# 11                  Fireboy DML
# 12                H.C. McEntire
# 13            The Front Bottoms
# 14        Mary Chapin Carpenter
# 15                 Nubya Garcia
# 16                     Cut Copy
# 17             John Vanderslice
# 18                       Matmos
# 19                        Bully
# 20                  Troye Sivan
# 21                       Sneaks
# 22                     Spun Out
# 23              Miranda Lambert
#
#                                                 album score  \
# 0                                          Pussy Cats   7.8
# 1                                        Papi Juancho   6.6
# 2                              Mi specchio e rifletto   7.8
# 3                                               Smile   5.7
# 4                                   Crabs in a Bucket   7.0
# 5                                            Shabrang   7.8
# 6                                        Primal Forms   7.7
# 7                                      King’s Disease   6.3
# 8                                          Motherhood   8.0
# 9                       Well Groomed (Original Score)   7.4
# 10                                Load It Up, Vol. 01   7.5
# 11                                             APOLLO   8.3
# 12                                           Eno Axis   8.1
# 13                            In Sickness & In Flames   5.6
# 14                             The Dirt and the Stars   7.7
# 15                                             Source   8.3
# 16                                       Freeze, Melt   6.5
# 17                                       eeeeeeep! EP   6.8
# 18  The Consuming Flame: Open Exercises in Group Form   6.9
# 19                                           SUGAREGG   7.7
# 20                                      In a Dream EP   7.6
# 21                                     Happy Birthday   7.1
# 22                                    Touch the Sound   7.5
# 23                                Crazy Ex-Girlfriend   8.0
#
#                     labels                        genres  year  \
# 0             [RCA Victor]                        [Rock]  1974
# 1       [Sony Music Latin]        [Global, Pop/R&B, Rap]  2020
# 2          [Unseen Worlds]  [Experimental, Folk/Country]  2020
# 3                [Capitol]                     [Pop/R&B]  2020
# 4                 [Warner]                         [Rap]  2020
# 5       [Twisted Elegance]                     [Pop/R&B]  2020
# 6       [Cosmo Rhythmatic]    [Electronic, Experimental]  2020
# 7            [Mass Appeal]                         [Rap]  2020
# 8           [Joyful Noise]                        [Rock]  2020
# 9                 [Domino]                  [Electronic]  2020
# 10                 [Alamo]                         [Rap]  2020
# 11          [YBNL, EMPIRE]                         [Rap]  2020
# 12                 [Merge]                        [Rock]  2020
# 13               [Elektra]                        [Rock]  2020
# 14         [Lambent Light]                [Folk/Country]  2020
# 15          [Concord Jazz]                        [Jazz]  2020
# 16  [Cutters, The Orchard]                        [Rock]  2020
# 17        [Tiny Telephone]                        [Rock]  2020
# 18         [Thrill Jockey]                [Experimental]  2020
# 19               [Sub Pop]                        [Rock]  2020
# 20               [Capitol]                     [Pop/R&B]  2020
# 21                 [Merge]                        [Rock]  2020
# 22                 [Shuga]                        [Rock]  2020
# 23              [Columbia]                [Folk/Country]  2007
#
#                 reviewer                         title        pub_date  \
# 0          Jayson Greene           Contributing Editor      16 hrs ago
# 1    Matthew Ismael Ruiz  Associate Staff Writer, News  August 29 2020
# 2         Allison Hussey  Associate Staff Writer, News  August 29 2020
# 3             Dani Blum                   Contributor   August 28 2020
# 4         Will Pritchard                  Contributor   August 28 2020
# 5         Colin Lodewick                   Contributor  August 28 2020
# 6              Ray Philp                          None  August 28 2020
# 7          Pete Tosiello                   Contributor  August 27 2020
# 8         Evan Rytlewski                   Contributor  August 27 2020
# 9   Marty Sartini Garner                   Contributor  August 27 2020
# 10       Mano Sundaresan                   Contributor  August 27 2020
# 11              Ivie Ani                          None  August 26 2020
# 12     Abigail Covington                   Contributor  August 26 2020
# 13            Julia Gray                          None  August 26 2020
# 14          Sam Sodomsky                  Staff Writer  August 26 2020
# 15             Andy Beta                   Contributor  August 25 2020
# 16          Jesse Dorris                   Contributor  August 25 2020
# 17        Zach Schonfeld                   Contributor  August 25 2020
# 18      Philip Sherburne           Contributing Editor  August 25 2020
# 19        Quinn Moreland                  Staff Writer  August 24 2020
# 20         Shaad D’Souza                  Contributor   August 24 2020
# 21        Zach Schonfeld                   Contributor  August 24 2020
# 22        Arielle Gordon                   Contributor  August 24 2020
# 23          Sam Sodomsky                  Staff Writer  August 23 2020
#
#                                              abstract  \
# 0   Each Sunday, Pitchfork takes an in-depth look ...
# 1   The Colombian pop star’s latest is low stakes,...
# 2   Inspired by poet Alda Merini, the Italian viol...
# 3   Katy Perry’s bubbly, cliché-ridden pop feels e...
# 4   On the UK road rapper’s heavy third album, Nin...
# 5   On her sophomore album, the singer examines go...
# 6   The Polish clarinetist Wacław Zimpel blows awa...
# 7   The Queensbridge legend’s 13th album marks a r...
# 8   On their fearlessly creative, beat-heavy new r...
# 9   The rainbow-colored pups of Rebecca Stern’s do...
# 10  The latest from the incarcerated L.A. rapper, ...
# 11  The rising Nigerian singer is on the vanguard ...
# 12  With spacious live takes and poetic lyricism, ...
# 13  The New Jersey duo’s seventh album sacrifices ...
# 14  Three decades into her career, one of country ...
# 15  On her stunning debut, the tenor saxophonist a...
# 16  The Australian electro-pop veterans return wit...
# 17  The analog master’s first all-digital release ...
# 18  This striking release from the eclectic duo br...
# 19  Reintroducing her band as a solo project, Alic...
# 20  The Australian pop singer finds freedom in the...
# 21  The post-punk rebel incorporates elements of h...
# 22  The debut from the Chicago trio tempers grandi...
# 23  Each Sunday, Pitchfork takes an in-depth look ...
#
#                                                review  \
# 0   If people know of Pussy Cats, they know at lea...
# 1   Can you really be macho if your best work come...
# 2   Featured Tracks:Play Track“La forza del canto”...
# 3   Between rows of Spandex at Forever 21, in the ...
# 4   On Christmas Eve 2011, UK road rapper Nines up...
# 5   Sevdaliza approaches her sophomore album Shabr...
# 6   Featured Tracks:Play TrackPrimal Forms — Shack...
# 7   By all measures, the rollout of 2018’s NASIR, ...
# 8   Perhaps it was inevitable that shoegaze would ...
# 9   If you were making a documentary about people ...
# 10  In a summer declared “lost” by partygoers and ...
# 11  Apollo, one of the most complex characters of ...
# 12  Featured Tracks:Play Track“Hands for the Harve...
# 13  The Front Bottoms made their name singing anth...
# 14  More than three decades into her career as one...
# 15  Featured Tracks:Play Track“Pace” — Nubya Garci...
# 16  Featured Tracks:Play TrackLove Is All We Share...
# 17  Featured Tracks:Play Track“lure mice condemn e...
# 18  Matmos’ high-concept investigations take narro...
# 19  At 29, Bully’s Alicia Bognanno could teach a m...
# 20  Featured Tracks:Play Track“Stud” — Troye Sivan...
# 21  Featured Tracks:Play Track“Mars in Virgo” — Sn...
# 22  The maximalist mentality that prevails through...
# 23  Miranda Lambert will not tolerate beach balls ...
#
#                                                   art
# 0   src="https://media.pitchfork.com/photos/5f4680...
# 1   src="https://media.pitchfork.com/photos/5f4524...
# 2   src="https://media.pitchfork.com/photos/5f4534...
# 3   src="https://media.pitchfork.com/photos/5f4538...
# 4   src="https://media.pitchfork.com/photos/5f4695...
# 5   src="https://media.pitchfork.com/photos/5f4674...
# 6   src="https://media.pitchfork.com/photos/5f3168...
# 7   src="https://media.pitchfork.com/photos/5f451c...
# 8   src="https://media.pitchfork.com/photos/5f43dd...
# 9   src="https://media.pitchfork.com/photos/5f451a...
# 10  src="https://media.pitchfork.com/photos/5f465e...
# 11  src="https://media.pitchfork.com/photos/5f3fef...
# 12  src="https://media.pitchfork.com/photos/5f35b4...
# 13  src="https://media.pitchfork.com/photos/5f43d5...
# 14  src="https://media.pitchfork.com/photos/5f3563...
# 15  src="https://media.pitchfork.com/photos/5f43d0...
# 16  src="https://media.pitchfork.com/photos/5f43c2...
# 17  src="https://media.pitchfork.com/photos/5f43d3...
# 18  src="https://media.pitchfork.com/photos/5f43cd...
# 19  src="https://media.pitchfork.com/photos/5f3fed...
# 20  src="https://media.pitchfork.com/photos/5f3ad1...
# 21  src="https://media.pitchfork.com/photos/5f3fd9...
# 22  src="https://media.pitchfork.com/photos/5f3ed0...
# 23  src="https://media.pitchfork.com/photos/5f3ffe...
